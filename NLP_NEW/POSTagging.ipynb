# %%
import spacy
import pandas as pd

# SpaCy modelini yükleyin (örn. İngilizce için)
nlp = spacy.load("en_core_web_sm")

# CSV dosyanızı okuyun (dosya yolunu ve adını güncelleyin)
df = pd.read_csv("C:\\Users\\catsu\\PycharmProjects\\scrappyhotel\\final_processed_reviews_deepl_use.csv")

# CSV dosyasındaki sütun adlarını yazdırın, böylece hangi sütunu kullanacağınızı belirleyin
print("Mevcut sütunlar:", df.columns)

# Örneğin, eğer doğru sütun adı 'final_processed_review' ise:
for idx, text in enumerate(df["processed_final_review"], start=1):
    print(f"--- Review {idx} ---")
    doc = nlp(text)

    # POS Tagging İşlemi
    print("\n[POS Tagging]")
    for token in doc:
        # token.text: orijinal kelime, token.pos_: genel POS etiketi, token.tag_: detaylı POS etiketi
        print(f"{token.text}\t{token.pos_}\t{token.tag_}")

    # Named Entity Recognition (NER) İşlemi
    print("\n[Named Entities]")
    if doc.ents:
        for ent in doc.ents:
            print(f"{ent.text}\t({ent.label_})")
    else:
        print("Bu metinde tespit edilmiş varlık bulunamadı.")

    print("\n" + "=" * 50 + "\n")
# Out:
# Mevcut sütunlar: Index(['hotel_name', 'author_name', 'language', 'review_text',
#        'processed_review', 'processed_final_review'],
#       dtype='object')
# --- Review 1 ---
#
# [POS Tagging]
# stay	VERB	VB
# cheap	ADJ	JJ
# narrow	ADJ	JJ
# room	NOUN	NN
# know	VERB	VBP
# needed	VERB	VBN
# room	NOUN	NN
# could	AUX	MD
# spend	VERB	VB
# night	NOUN	NN
# look	VERB	VB
# hotel	NOUN	NN
# cheap	ADJ	JJ
# room	NOUN	NN
# enough	ADJ	JJ
# room	NOUN	NN
# really	ADV	RB
# small	ADJ	JJ
# bed	NOUN	NN
# really	ADV	RB
# small	ADJ	JJ
# except	SCONJ	IN
# mini	ADJ	JJ
# fridge	NOUN	NN
# want	VERB	VBP
# open	ADJ	JJ
# large	ADJ	JJ
# suitcase	NOUN	NN
# not	PART	RB
# open	ADJ	JJ
# bathroom	NOUN	NN
# toilet	NOUN	NN
# enough	ADJ	JJ
# room	NOUN	NN
# give	VERB	VBP
# night	NOUN	NN
# provide	VERB	VB
# with	ADP	IN
# basic	ADJ	JJ
# condition	NOUN	NN
# stay	VERB	VB
# bed	NOUN	NN
# pillow	VERB	VBP
# comfortable	ADJ	JJ
# toilet	NOUN	NN
# bathroom	NOUN	NN
# clean	ADJ	JJ
# stay	PROPN	NNP
# night	NOUN	NN
# want	VERB	VBP
# ...

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import spacy
from spacy import displacy
import pandas as pd

# SpaCy modelini yükleyin (örn. İngilizce için)
nlp = spacy.load("en_core_web_sm")

# CSV dosyanızı okuyun (dosya yolunu ve adını güncelleyin)
df = pd.read_csv("C:\\Users\\catsu\\PycharmProjects\\scrappyhotel\\final_processed_reviews_deepl_use.csv")

# CSV dosyasındaki sütun adlarını yazdırın, böylece hangi sütunu kullanacağınızı belirleyin
print("Mevcut sütunlar:", df.columns)

# Örneğin, eğer doğru sütun adı 'processed_final_review' ise:
for idx, text in enumerate(df["processed_final_review"], start=1):
    print(f"--- Review {idx} ---")
    
    # Yorum metnini spaCy ile işleyelim.
    doc = nlp(text)
    
    # POS Tagging İşlemi
    print("\n[POS Tagging]")
    for token in doc:
        # token.text: orijinal kelime, token.pos_: genel POS etiketi, token.tag_: detaylı POS etiketi
        print(f"{token.text}\t{token.pos_}\t{token.tag_}")
    
    # Named Entity Recognition (NER) İşlemi
    print("\n[Named Entities]")
    if doc.ents:
        for ent in doc.ents:
            print(f"{ent.text}\t({ent.label_})")
    else:
        print("Bu metinde tespit edilmiş varlık bulunamadı.")
    
    # Görselleştirme: Yalnızca ilk 10 yorum için NER görsel çıktısını gösterelim.
    if idx <= 10:
        print("\n[NER Görselleştirme]")
        displacy.render(doc, style='ent', jupyter=True, options={'distance': 150})
        print("\n[Dependency Görselleştirme]")
        displacy.render(doc, style='dep', jupyter=True, options={'distance': 120})
    else:
        print("\n[NER Görselleştirme atlandı]")
    
    print("\n" + "=" * 50 + "\n")
# Out:
# Mevcut sütunlar: Index(['hotel_name', 'author_name', 'language', 'review_text',
#        'processed_review', 'processed_final_review'],
#       dtype='object')
# --- Review 1 ---
#
# [POS Tagging]
# stay	VERB	VB
# cheap	ADJ	JJ
# narrow	ADJ	JJ
# room	NOUN	NN
# know	VERB	VBP
# needed	VERB	VBN
# room	NOUN	NN
# could	AUX	MD
# spend	VERB	VB
# night	NOUN	NN
# look	VERB	VB
# hotel	NOUN	NN
# cheap	ADJ	JJ
# room	NOUN	NN
# enough	ADJ	JJ
# room	NOUN	NN
# really	ADV	RB
# small	ADJ	JJ
# bed	NOUN	NN
# really	ADV	RB
# small	ADJ	JJ
# except	SCONJ	IN
# mini	ADJ	JJ
# fridge	NOUN	NN
# want	VERB	VBP
# open	ADJ	JJ
# large	ADJ	JJ
# suitcase	NOUN	NN
# not	PART	RB
# open	ADJ	JJ
# bathroom	NOUN	NN
# toilet	NOUN	NN
# enough	ADJ	JJ
# room	NOUN	NN
# give	VERB	VBP
# night	NOUN	NN
# provide	VERB	VB
# with	ADP	IN
# basic	ADJ	JJ
# condition	NOUN	NN
# stay	VERB	VB
# bed	NOUN	NN
# pillow	VERB	VBP
# comfortable	ADJ	JJ
# toilet	NOUN	NN
# bathroom	NOUN	NN
# clean	ADJ	JJ
# stay	PROPN	NNP
# night	NOUN	NN
# want	VERB	VBP
# ...
